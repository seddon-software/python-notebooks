# %% [markdown]
# <div style="color:red;background-color:black">
# Diamond Light Source
#
# <h1 style="color:red;background-color:antiquewhite"> Python Fundamentals: Sympy</h1>
#
# ©2000-20 Chris Seddon
# </div>

# %% [markdown]
# Execute the following cell to activate styling for this tutorial

# %%
from IPython.display import HTML
HTML(f"<style>{open('my.css').read()}</style>")
# Out:
# <style>/* GLOBALS */
# /* body {background-color: #f7f7f7;} */
# .text_cell {background-color: cornsilk;}
# .code_cell { background-color: lightskyblue; }
# .selected { background-color: peachpuff; }
# .output { background-color: aliceblue; }
#
# </style>

# %% [markdown]
# SymPy is an open-source Python library for symbolic computation.  In this tutorial we will be looking at how to use SymPy using various examples.

# %% [markdown]
# ## Polynomials: 1
# Define a polynomial with three unknowns.  Note the fancy output:

# %%
import sympy
sympy.init_printing()

# define symbols
x , y , z = sympy.symbols('x, y, z')

# print polynominal 
2*(x - 3)**3 + 5*y/z
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# 5⋅y            3
# ─── + 2⋅(x - 3)
#  z

# %% [markdown]
# ## Polynomials: 2
# Use matplotlib to plot a cubic polynomial.

# %%
# %matplotlib inline
import numpy as np
import pylab as plt
X = np.arange(-50, 50, 0.01)
Y = 2*(X-3)**3

# plot the curve
plt.plot(X, Y, color='red', lw=2)
plt.grid()
plt.show()

# %% [markdown]
# ## Polynomials: 3
# Expand a polynomial expression to standard form:

# %%
# expand expression
(2*(x - 3)**3).expand()
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
#    3       2
# 2⋅x  - 18⋅x  + 54⋅x - 54

# %% [markdown]
# ## Polynomials: 4
# Evaluate a polynomial expression when x = 10:

# %%
# evaluate polynominal with a given value of x
((x + 2*y)**2).subs(x, 10)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
#           2
# (2⋅y + 10)

# %% [markdown]
# ## Polynomials: 5
# Evaluate a polynomial expression when x = 10 and y = 3:

# %%
# evaluate polynominal with a given values of x and y
((x + 2*y)**2).subs({x:10, y:3})
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# 256

# %% [markdown]
# ## Polynomials: 5
# Evaluate a polynomial expression twice.  First substitute x = y and then set y = 3:

# %%
# perform double substitution on expression 
((x + 2*y)**2).subs(x, y).subs(y, 2)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# 36

# %% [markdown]
# ## Rational Numbers: 1
# Sympy allows us to work with rational numbers (fractions):

# %%
from sympy import *
import sympy
sympy.init_printing()
a, b = sympy.symbols('a, b')

# print 0.7 as a fraction 
a = Rational(7, 10)
a
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# 7/10

# %% [markdown]
# ## Rational Numbers: 2
# Display a*b and a+b as fractions:

# %%
# print an expression as a fraction 
a = Rational(7, 10)
b = Rational (45 , 67)
a * b, a + b
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# ⎛ 63  919⎞
# ⎜───, ───⎟
# ⎝134  670⎠

# %% [markdown]
# ## Rational Numbers: 3
# Display a*b as a float:

# %%
# print same data as a float
(float)(a + b)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# 1.371641791044776

# %% [markdown]
# ## Rational Numbers: 3
# Display a*b with 27 decimal places of precision:

# %%
# print to 27 decimal places
(a + b).evalf(27)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# 1.37164179104477611940298507

# %% [markdown]
# ## Differentiation: 1
# Find the differentional of sin(x):

# %%
from sympy import Derivative, symbols, exp, sin, sqrt, diff
import sympy
sympy.init_printing()
x, y = symbols('x, y')
Derivative( sin(x), x ), diff( sin(x), x )
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# ⎛d                 ⎞
# ⎜──(sin(x)), cos(x)⎟
# ⎝dx                ⎠

# %% [markdown]
# ## Differentiation: 2
# Find the differentional of a polynomial:

# %%
expression = 10 + 3*x + 4*y + 10*x**2 + x**9
Derivative(expression, x), diff(expression, x)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# ⎛∂ ⎛ 9       2                 ⎞     8           ⎞
# ⎜──⎝x  + 10⋅x  + 3⋅x + 4⋅y + 10⎠, 9⋅x  + 20⋅x + 3⎟
# ⎝∂x                                              ⎠

# %% [markdown]
# ## Differentiation: 3
# Differentiate and then evaluate a polynomial when x = 1.5:

# %%
# evaluate when x = 1.5
expression = 10 + 3*x + 4*y + 10*x**2 + x**9
Derivative(expression, x), diff(expression, x).subs(x, 1.5)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# ⎛∂ ⎛ 9       2                 ⎞              ⎞
# ⎜──⎝x  + 10⋅x  + 3⋅x + 4⋅y + 10⎠, 263.66015625⎟
# ⎝∂x                                           ⎠

# %% [markdown]
# ## Differentiation: 4
# Differentiate an exponential expression:

# %%
Derivative(exp(-x**2/2), x), diff(exp(-x**2/2), x)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# ⎛  ⎛   2 ⎞        2 ⎞
# ⎜  ⎜ -x  ⎟      -x  ⎟
# ⎜  ⎜ ────⎟      ────⎟
# ⎜d ⎜  2  ⎟       2  ⎟
# ⎜──⎝ℯ    ⎠, -x⋅ℯ    ⎟
# ⎝dx                 ⎠

# %% [markdown]
# ## Differentiation: 5
# Triple differentiation:

# %%
Derivative(3*x**4, x, x, x), diff(3*x**4, x, x, x)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# ⎛  3            ⎞
# ⎜ d ⎛   4⎞      ⎟
# ⎜───⎝3⋅x ⎠, 72⋅x⎟
# ⎜  3            ⎟
# ⎝dx             ⎠

# %% [markdown]
# ## Integration: 1
# Simple integration

# %%
import sympy
from sympy import Integral, Eq, integrate, sin, exp
sympy.init_printing()

x, y, sigma = sympy.symbols('x, y, sigma')
Eq(Integral(x**2, x), integrate(x**2, x))
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# ⌠          3
# ⎮  2      x
# ⎮ x  dx = ──
# ⌡         3

# %% [markdown]
# ## Integration: 2
# Integration with two variables, x and y.  The variable x is considered constant:

# %%
Eq(Integral(x**2, y), integrate(x**2, y))
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# ⌠
# ⎮  2       2
# ⎮ x  dy = x ⋅y
# ⌡

# %% [markdown]
# ## Integration: 3
# Integration with the same two variables, x and y.  This time we create tuple for the function and derivative variable of the form:<pre>t1 = ((sin(x), x)</pre>
# Recall that <pre>*t1</pre>
# expands the tuple.  x is variable in the first example, but constant in the second example:

# %%
t1 = (sin(x), x)
t2 = (sin(x), y)
Eq(Integral(*t1), integrate(*t1)), Eq(Integral(*t2), integrate(*t2))
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# ⎛⌠                      ⌠                     ⎞
# ⎜⎮ sin(x) dx = -cos(x), ⎮ sin(x) dy = y⋅sin(x)⎟
# ⎝⌡                      ⌡                     ⎠

# %% [markdown]
# ## Integration: 4
# Integration with an exponential:

# %%
e = (-x * exp(-x**2/2), x)
Eq(Integral(*e), integrate(*e))
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# ⌠
# ⎮       2          2
# ⎮     -x         -x
# ⎮     ────       ────
# ⎮      2          2
# ⎮ -x⋅ℯ     dx = ℯ
# ⌡

# %% [markdown]
# ## Integration: 5
# Triple integration.  <pre>Integral(x\**2, x, x, y)</pre>
# means integrate x**2 with respect to dx, dx and finally dy.

# %%
# triple integral
Eq(Integral(x**2, x, x, y), integrate(x**2, x, x, y))
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# ⌠ ⌠ ⌠                4
# ⎮ ⎮ ⎮  2            x ⋅y
# ⎮ ⎮ ⎮ x  dx dx dy = ────
# ⌡ ⌡ ⌡                12

# %% [markdown]
# ## Integration: 5
# Partial integration; the last integral is a definite integral:

# %%
# partially evaluate integral
e = (x**2, (x,0,2), x, y)
Integral(*e), integrate(*e)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# ⎛    2                   ⎞
# ⎜⌠ ⌠ ⌠                   ⎟
# ⎜⎮ ⎮ ⎮  2           8⋅x⋅y⎟
# ⎜⎮ ⎮ ⎮ x  dx dx dy, ─────⎟
# ⎜⌡ ⌡ ⌡                3  ⎟
# ⎝    0                   ⎠

# %% [markdown]
# ## Integration: 5
# Triple integration; all definite integrals:

# %%
# fully evaluate integral
e = (x**2, (x,0,2), (x,0,2), (y,0,1))
Eq(Integral(*e), integrate(*e))
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# 1 2 2
# ⌠ ⌠ ⌠
# ⎮ ⎮ ⎮  2
# ⎮ ⎮ ⎮ x  dx dx dy = 16/3
# ⌡ ⌡ ⌡
# 0 0 0

# %% [markdown]
# ## Differential Equations: 1
#
# We'll attempt to solve the differential equation below:

# %%
import sympy
from sympy import Symbol , dsolve , Function , Derivative , Eq
sympy.init_printing()

x , y , z = sympy.symbols('x, y, z')

y = Function("y")
x = Symbol("x")
d = Derivative(y(x), x)
Eq(d + 5*y(x), 12)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
#          d
# 5⋅y(x) + ──(y(x)) = 12
#          dx

# %% [markdown]
# ## Differential Equations: 2
#
# The solution is:

# %%
# constant = 2, x = 5
dsolve( Eq(d + 5*y(x), 12), y(x))
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
#            -5⋅x
#        C₁⋅ℯ       12
# y(x) = ──────── + ──
#           5       5

# %% [markdown]
# ## Differential Equations: 3
#
# If we know the constant is 2 and x = 5:

# %%
C1 = Symbol("C1")
dsolve( Eq(d + 5*y(x), 12), y(x)).subs({C1:2, x:5})
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
#           -25
#        2⋅ℯ      12
# y(5) = ────── + ──
#          5      5

# %% [markdown]
# ## Differential Equations: 4
#
# ... or the solution as a float:

# %%
# to 20 significant figures ...
dsolve( Eq(d + 5*y(x), 12), y(x)).subs({C1:2, x:5}).evalf(20)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
# y(5) = 2.4000000000055551775

# %% [markdown]
# ## Taylor Series: 1
# Find the Taylor series expansion of cos(x) around x = 0.5.  Work to 4 decimal places and stop the expansion after 10 terms:

# %%
import sympy
from sympy import Symbol, Rational, cos, sin, series
sympy.init_printing()

x = Symbol('x') 
cos(x).series(x0=0.5, n=10).evalf(4)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
#                         2                   3                    4
# 1.117 - 0.4388⋅(x - 0.5)  + 0.0799⋅(x - 0.5)  + 0.03657⋅(x - 0.5)  - 0.003995⋅
#
#          5                     6                     7                     8
# (x - 0.5)  - 0.001219⋅(x - 0.5)  + 9.512e-5⋅(x - 0.5)  + 2.177e-5⋅(x - 0.5)  -
#
#                    9               ⎛         10         ⎞
#  1.321e-6⋅(x - 0.5)  - 0.4794⋅x + O⎝(x - 0.5)  ; x → 0.5⎠

# %% [markdown]
# ## Taylor Series: 2
# It's much clearer if we use rationals (fractions):

# %%
cos(x).series(x0=Rational(0.5), n=10)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
#                                          2                     3
#                                 (x - 1/2) ⋅cos(1/2)   (x - 1/2) ⋅sin(1/2)   (x
# cos(1/2) - (x - 1/2)⋅sin(1/2) - ─────────────────── + ─────────────────── + ──
#                                          2                     6
#
#        4                     5                     6                     7
#  - 1/2) ⋅cos(1/2)   (x - 1/2) ⋅sin(1/2)   (x - 1/2) ⋅cos(1/2)   (x - 1/2) ⋅sin
# ───────────────── - ─────────────────── - ─────────────────── + ──────────────
#        24                   120                   720                   5040
#
#                  8                     9
# (1/2)   (x - 1/2) ⋅cos(1/2)   (x - 1/2) ⋅sin(1/2)    ⎛         10         ⎞
# ───── + ─────────────────── - ─────────────────── + O⎝(x - 1/2)  ; x → 1/2⎠
#                40320                 362880

# %% [markdown]
# ## Taylor Series: 3
# We can remove the error term:

# %%
cos(x).series(x0=Rational(0.5), n=10).removeO()
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
#            9                     8                     7                     6
#   (x - 1/2) ⋅sin(1/2)   (x - 1/2) ⋅cos(1/2)   (x - 1/2) ⋅sin(1/2)   (x - 1/2)
# - ─────────────────── + ─────────────────── + ─────────────────── - ──────────
#          362880                40320                  5040                  72
#
#                      5                     4                     3
# ⋅cos(1/2)   (x - 1/2) ⋅sin(1/2)   (x - 1/2) ⋅cos(1/2)   (x - 1/2) ⋅sin(1/2)
# ───────── - ─────────────────── + ─────────────────── + ─────────────────── -
# 0                   120                    24                    6
#
#          2
# (x - 1/2) ⋅cos(1/2)
# ─────────────────── - (x - 1/2)⋅sin(1/2) + cos(1/2)
#          2

# %% [markdown]
# ## Taylor Series: 4
# We can get the MacLauren series by expanding around x = 0:

# %%
series(cos(x), x0=0, n=10)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     209                          stderr=STDOUT,
# --> 210                          creationflags=creation_flag)
#     211         except CalledProcessError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-halt-on-error', '-interaction=nonstopmode', 'texput.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     153             try:
# --> 154                 return _preview_wrapper(s)
#     155             except RuntimeError as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _preview_wrapper(o)
#      75                     outputbuffer=exprbuffer, preamble=preamble,
# ---> 76                     dvioptions=dvioptions)
#      77         except Exception as e:
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/printing/preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     213                 "'latex' exited abnormally with the following output:\n%s" %
# --> 214                 e.output)
#     215
#
# RuntimeError: 'latex' exited abnormally with the following output:
# b"This is pdfTeX, Version 3.1415926-2.5-1.40.14 (TeX Live 2013)\n restricted \\write18 enabled.\nentering extended mode\n(./texput.tex\nLaTeX2e <2011/06/27>\nBabel <v3.8m> and hyphenation patterns for english, dumylang, nohyphenation, lo\naded.\n\n! LaTeX Error: File `standalone.cls' not found.\n\nType X to quit or <RETURN> to proceed,\nor enter new name. (Default extension: cls)\n\nEnter file name: \n! Emergency stop.\n<read *> \n         \nl.2 \\usepackage\n               {amsmath,amsfonts}\\begin{document}^^M\nNo pages of output.\nTranscript written on texput.log.\n"
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _print_latex_png(o)
#     158                 if latex_mode != 'inline':
#     159                     s = latex(o, mode='inline', **settings)
# --> 160                 return _matplotlib_wrapper(s)
#     161
#     162     def _print_latex_matplotlib(o):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/sympy/interactive/printing.py in _matplotlib_wrapper(o)
#      91         # ensure that if mathtext fails to render, we return None.
#      92         try:
# ---> 93             return latex_to_png(o)
#      94         except ValueError as e:
#      95             debug('matplotlib exception caught:', repr(e))
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png(s, encode, backend, wrap, color, scale)
#     102     else:
#     103         raise ValueError('No such backend {0}'.format(backend))
# --> 104     bin_data = f(s, wrap, color, scale)
#     105     if encode and bin_data:
#     106         bin_data = encodebytes(bin_data)
#
# ~/.local/lib/python3.7/site-packages/IPython/lib/latextools.py in latex_to_png_mpl(s, wrap, color, scale)
#     124         f = BytesIO()
#     125         dpi = 120*scale
# --> 126         mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
#     127         return f.getvalue()
#     128     except (ValueError, RuntimeError, ParseFatalException):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/mathtext.py in to_png(self, filename, texstr, color, dpi, fontsize)
#    3434         rgba, depth = self.to_rgba(
#    3435             texstr, color=color, dpi=dpi, fontsize=fontsize)
# -> 3436         with open(filename, "wb") as file:
#    3437             _png.write_png(rgba, file)
#    3438         return depth
#
# TypeError: expected str, bytes or os.PathLike object, not _io.BytesIO
#      2    4     6      8
#     x    x     x      x      ⎛ 10⎞
# 1 - ── + ── - ─── + ───── + O⎝x  ⎠
#     2    24   720   40320

# %% [markdown]
# ## Non Linear Equations: 1
# We can solve some non linear equations if there is an analytical solution.  In this example we will be looking at solutions to:
# $$y = x - x^{2.5} + 7$$

# %%
import sympy

x, y = sympy.symbols('x, y')
eq = x - x**2.5 + 7
y = sympy.solve( eq, x )
 
# note some of the results are complex (I represents sqrt(-1))
for result in y:
    print(sympy.N(result, 5))    # N is used to limit precision
# Out:
# 2.4563
# -1.6748 - 1.031*I
# -1.6748 + 1.031*I

# %% [markdown]
# ## Non Linear Equations: 2
# Let's have a look at a plot of this function.  We will be plotting real and imaginary parts of y.
#
# Note that the Numpy "arange" method doesn't directly work with complex numbers.  What we have to do with x coordinates is to generate a "real" sequence and then multiply by 1 + 0j:<pre>X = (1 + 0j) * plt.arange(-5, 5, 0.1)</pre>

# %%
# %matplotlib inline
import sympy
import pylab as plt

plt.gca().set_title('Y = X - X**2.5 + 7')

# show the graph
X = (1 + 0j) * plt.arange(-5, 5, 0.1)
Y = X - X**2.5 + 7
plt.plot(X.real, Y.real, color='red', lw=2, label='real')
plt.plot(X.real, Y.imag, color='green', lw=2, label='imag')
plt.legend()

X = plt.arange(-5, 5, 0.1)
plt.grid()
plt.show()
